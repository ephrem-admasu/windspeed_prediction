# %%
import numpy as np
import matplotlib.pylab as plt
from math import *
#from sklearn.models import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn import svm
import pandas as pd
import seaborn as sns
from pylab import rcParams
from matplotlib import rc
from mpl_toolkits.mplot3d import Axes3D
import time
# %matplotlib notebook

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
RANDOM_SEED = 42
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
#HAPPY_COLORS_PALETTE = ['#01BEFE', '#FFDD00', '#FF7D00', '#FF006D', '#ADFF02', '#8F00FF']
#sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8

# %%
df = pd.read_csv('wind_only.csv')

# %%
df.shape
# Out:
# (8785, 1)

# %%
df.head()
# Out:
#      WS
# 0  7.08
# 1  7.18
# 2  7.00
# 3  7.03
# 4  7.64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(6, 4))
sns.displot(df['WS'])
plt.show()

# %%
highest = df['WS'].mean() + df['WS'].std()
lowest = df['WS'].mean() - df['WS'].std()

# %%
highest, lowest
# Out:
# (9.961681597735705, 4.683222773848992)

# %%
df[(df['WS'] > highest) | (df['WS'] < lowest)]
# Out:
#          WS
# 142   10.00
# 143   10.13
# 145   10.91
# 146   11.20
# 147   11.08
# ...     ...
# 8779   4.30
# 8780   4.23
# 8781   3.26
# 8782   3.44
# 8783   3.64
#
# [3085 rows x 1 columns]

# %%
new_df = df[(df['WS'] <= highest) & (df['WS'] >= lowest)]

# %%
sns.displot(new_df['WS'])

# %%
x = np.linspace(0,2*np.pi,100,endpoint=False)
y = np.sin(2*x) + np.cos(10*x+2.3)
        
#do the FIF analysis
import FIF

def fif_analysist(y):
    fif=FIF.FIF()
    fif.run(y)
    
    return fif

# %%
fif = fif_analysist(y)
# Out:
# IMF 1
# Max # of inner steps reached
# IMF 2
# Max # of inner steps reached
# IMF 3
# IMF 4
# IMF 5
# IMF 6
# IMF 7
# IMF 8
# IMF 9
# Max # of inner steps reached
# IMF 10
# Max # of inner steps reached
# IMF 11
# IMF 12
# IMF 13
# IMF 14

# %%
fif.data['IMC'].shape
# Out:
# (15, 100)
