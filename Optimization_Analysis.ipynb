# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from ebqpso import EBQPSO
from qpso import QPSO
from pyswarm import pso

# %%
import benchmark_functions as bf 
import numpy as np

# %%
num_runs = 10
n = 30
ebqspo_vals = []
qpso_vals = []
pso_vals = []

# %% [markdown]
# #### Testing Ackley function

# %%
# initialize Schwefel functions with four dimensions
func = bf.Ackley(n_dimensions=n)

# Initialize parameters
D = func.n_dimensions() # get num of dimensions from fun
nPop = 100
maxiter = 5000
lambda_ = 10
lb = func.suggested_bounds()[0]
ub = func.suggested_bounds()[1]

# for _ in range(num_runs):
#     _, e_fbest, _ = EBQPSO(func, D, nPop, lb, ub, maxiter, lambda_)
#     _, q_fbest, _ = QPSO(func, D, nPop, lb, ub, maxiter)
#     _, p_fbest = pso(func, lb, ub)

#     ebqspo_vals.append(e_fbest)
#     qpso_vals.append(q_fbest)
#     pso_vals.append(p_fbest)

# %%
for i in range(10):
    eb_gbest, eb_fbest, eb_hist = EBQPSO(func, D, nPop, lb, ub, maxiter, lambda_)
    ebqspo_vals.append(eb_fbest)

# %%
print("EBQPSO: ", np.mean(ebqspo_vals), " +/- ", np.std(ebqspo_vals))
# Out:
# EBQPSO:  1.7359850930502448e-15  +/-  1.7090176133679144e-15

# %%
for i in range(10):
    q_gbest, q_fbest, q_hist = QPSO(func, D, nPop, lb, ub, maxiter)
    qpso_vals.append(q_fbest)

# %%
print("QPSO: ", np.mean(qpso_vals), " +/- ", np.std(qpso_vals))
# Out:
# QPSO:  2.220446049250313e-15  +/-  1.7763568394002505e-15

# %%
for i in range(10):
    p_gbest, p_fbest = pso(func, lb, ub, swarmsize=nPop, maxiter=maxiter)
    pso_vals.append(p_fbest)
# Out:
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08

# %%
print("PSO: ", np.mean(pso_vals), " +/- ", np.std(pso_vals))
# Out:
# PSO:  11.743437104530916  +/-  1.994526010388795

# %%
def optimize(func, nPop, maxiter, optim_algo='EBQPSO', lambda_= 5, n = 2, num_runs=10):
    D = func.n_dimensions() # get num of dimensions from fun
    lb = func.suggested_bounds()[0]
    ub = func.suggested_bounds()[1]

    best_vals = []
    if optim_algo=='EBQPSO':
        for i in range(num_runs):
            _, fbest, _ = EBQPSO(func, n, nPop, lb, ub, maxiter, lambda_)
            best_vals.append(fbest)
    elif optim_algo=='QPSO':
        for i in range(num_runs):
            _, fbest, _ = QPSO(func, n, nPop, lb, ub, maxiter)
            best_vals.append(fbest)
    elif optim_algo=='PSO':
        for i in range(num_runs):
            _, fbest = pso(func, lb, ub, swarmsize=nPop, maxiter=maxiter)
            best_vals.append(fbest)
    return best_vals

# %% [markdown]
# #### Eggholder Function

# %%
func = bf.EggHolder(n_dimensions=2)
lb = func.suggested_bounds()[0]
ub = func.suggested_bounds()[1]

# %%
eb_bests = optimize(func, nPop, maxiter=maxiter, optim_algo='EBQPSO', n = 2)

# %%
np.mean(eb_bests), np.std(eb_bests)
# Out:
# (-959.6392802337826, 0.0015885257619249937)

# %%
q_bests = optimize(func, nPop, maxiter=maxiter, optim_algo='QPSO', n = 2)

# %%
np.mean(q_bests), np.std(q_bests)
# Out:
# (-959.622248114697, 0.025598272471941262)

# %%
p_bests = optimize(func, nPop, maxiter=maxiter, optim_algo='PSO', n = 2)
# Out:
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08
# Stopping search: Swarm best objective change less than 1e-08

# %%
np.mean(p_bests), np.std(p_bests)
# Out:
# (-895.9997754099404, 61.41886164071127)

# %%
def f(x):
    term_1 = 0
    term_2 = 0
    for i, xi in enumerate(x):
        term_1  = term_1 + xi**2
        term_2 = term_2 + (0.5*(i+1)*xi)
    return term_1 + term_2**2 + term_2**4

# %%
lb = [-5 for _ in range(n)]
ub = [10 for _ in range(n)]

# %%
n = 30
nPop = 100
maxiter = 5000

# %%
eb_bests = []
for i in range(num_runs):
    _, fbest, _ = EBQPSO(f, n, nPop, lb, ub, maxiter, lambda_)
    eb_bests.append(fbest)

# %%
np.mean(eb_bests), np.std(eb_bests)
# Out:
# (3.1924573683226383, 5.967218050656806)

# %%
help(bf.benchmark_functions)
# Out:
# Help on module benchmark_functions.benchmark_functions in benchmark_functions:
#
# NAME
#     benchmark_functions.benchmark_functions
#
# CLASSES
#     abc.ABC(builtins.object)
#         BenchmarkFunction
#             Ackley
#             DeJong3
#             DeJong5
#             Easom
#             EggHolder
#             GoldsteinAndPrice
#             Griewank
#             Himmelblau
#             Hyperellipsoid
#             Hypersphere
#             Keane
#             MartinGaddy
#             McCormick
#             Michalewicz
#             PichenyGoldsteinAndPrice
#             PitsAndHoles
#             Rana
#             Rastrigin
#             Rosenbrock
#             Schaffer2
#             Schwefel
#             StyblinskiTang
#
#     class Ackley(BenchmarkFunction)
#      |  Ackley(n_dimensions=2, a=20, b=0.2, c=6.283185307179586, opposite=False)
#      |
#      |  Method resolution order:
#      |      Ackley
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, a=20, b=0.2, c=6.283185307179586, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class BenchmarkFunction(abc.ABC)
#      |  BenchmarkFunction(name, n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  __init__(self, name, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset({'_evaluate'})
#
#     class DeJong3(BenchmarkFunction)
#      |  DeJong3(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      DeJong3
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class DeJong5(BenchmarkFunction)
#      |  DeJong5(opposite=False)
#      |
#      |  Method resolution order:
#      |      DeJong5
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Easom(BenchmarkFunction)
#      |  Easom(opposite=False)
#      |
#      |  Method resolution order:
#      |      Easom
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class EggHolder(BenchmarkFunction)
#      |  EggHolder(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      EggHolder
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class GoldsteinAndPrice(BenchmarkFunction)
#      |  GoldsteinAndPrice(opposite=False)
#      |
#      |  Method resolution order:
#      |      GoldsteinAndPrice
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Griewank(BenchmarkFunction)
#      |  Griewank(n_dimensions=2, zoom=0, opposite=False)
#      |
#      |  Method resolution order:
#      |      Griewank
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, zoom=0, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  getName(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Himmelblau(BenchmarkFunction)
#      |  Himmelblau(opposite=False)
#      |
#      |  Method resolution order:
#      |      Himmelblau
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Hyperellipsoid(BenchmarkFunction)
#      |  Hyperellipsoid(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      Hyperellipsoid
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Hypersphere(BenchmarkFunction)
#      |  Hypersphere(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      Hypersphere
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Keane(BenchmarkFunction)
#      |  Keane(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      Keane
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  validate(self, point)
#      |      # validate the point according the Keane's function conditions
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class MartinGaddy(BenchmarkFunction)
#      |  MartinGaddy(opposite=False)
#      |
#      |  Method resolution order:
#      |      MartinGaddy
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class McCormick(BenchmarkFunction)
#      |  McCormick(opposite=False)
#      |
#      |  Method resolution order:
#      |      McCormick
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Michalewicz(BenchmarkFunction)
#      |  Michalewicz(n_dimensions=2, m=10, opposite=False)
#      |
#      |  Method resolution order:
#      |      Michalewicz
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, m=10, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class PichenyGoldsteinAndPrice(BenchmarkFunction)
#      |  PichenyGoldsteinAndPrice(opposite=False)
#      |
#      |  Method resolution order:
#      |      PichenyGoldsteinAndPrice
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
# ...
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Schaffer2(BenchmarkFunction)
#      |  Schaffer2(opposite=False)
#      |
#      |  Method resolution order:
#      |      Schaffer2
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Schwefel(BenchmarkFunction)
#      |  Schwefel(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      Schwefel
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class StyblinskiTang(BenchmarkFunction)
#      |  StyblinskiTang(n_dimensions=2, opposite=False)
#      |
#      |  Method resolution order:
#      |      StyblinskiTang
#      |      BenchmarkFunction
#      |      abc.ABC
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n_dimensions=2, opposite=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BenchmarkFunction:
#      |
#      |  __call__(self, point, validate=True)
#      |      Call self as a function.
#      |
#      |  definition(self)
#      |
#      |  dev_comment(self)
#      |
#      |  gradient(self, point, validate=True)
#      |
#      |  hessian(self, point, validate=True)
#      |      # This returns always a numpy array
#      |
#      |  load_info(self, force_reload=False)
#      |
#      |  maxima(self)
#      |
#      |  maximum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minima(self)
#      |
#      |  minimum(self)
#      |      # returns an object of type Optimum
#      |
#      |  minimum_grid_search(self, bounds, n_edge_points=100, score_threshold=0.0)
#      |
#      |  minimum_random_search(self, bounds, n_samples=10000000, score_threshold=0.0)
#      |
#      |  n_dimensions(self)
#      |
#      |  n_maxima(self)
#      |      # @return a dictionary {n_dimension: n_maxima} with the number of known minima per each dimension. If dimension-invariant maxima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_minima(self)
#      |      # @return a dictionary {n_dimension: n_minima} with the number of known minima per each dimension. If dimension-invariant minima are known, a '*' char will be present in place of n_dimension
#      |
#      |  n_saddle_points(self)
#      |      # @return a dictionary {n_dimension: n_saddle_points} with the number of known saddle points per each dimension. If dimension-invariant saddle points are known, a '*' char will be present in place of n_dimension
#      |
#      |  name(self)
#      |
#      |  reference(self)
#      |
#      |  saddle_points(self)
#      |
#      |  show(self, bounds=None, asHeatMap=False, resolution=50, showPoints=[])
#      |
#      |  suggested_bounds(self)
#      |
#      |  summary(self)
#      |
#      |  testLocalMinimum(self, potential_minimum, radius_factor=1e-10, score_threshold=1e-06, n_tests=100000, strict=True)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BenchmarkFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# DATA
#     multivariate_normal = <scipy.stats._multivariate.multivariate_normal_g...
#         A multivariate normal random variable.
#
#         The `mean` keyword specifies the mean. The `cov` keyword specifies the
#         covariance matrix.
#
#         Methods
#         -------
#         pdf(x, mean=None, cov=1, allow_singular=False)
#             Probability density function.
#         logpdf(x, mean=None, cov=1, allow_singular=False)
#             Log of the probability density function.
#         cdf(x, mean=None, cov=1, allow_singular=False, maxpts=1000000*dim, abseps=1e-5, releps=1e-5, lower_limit=None)  # noqa
#             Cumulative distribution function.
#         logcdf(x, mean=None, cov=1, allow_singular=False, maxpts=1000000*dim, abseps=1e-5, releps=1e-5)
#             Log of the cumulative distribution function.
#         rvs(mean=None, cov=1, size=1, random_state=None)
#             Draw random samples from a multivariate normal distribution.
#         entropy()
#             Compute the differential entropy of the multivariate normal.
#
#         Parameters
#         ----------
#         mean : array_like, default: ``[0]``
#             Mean of the distribution.
#         cov : array_like or `Covariance`, default: ``[1]``
#             Symmetric positive (semi)definite covariance matrix of the distribution.
#         allow_singular : bool, default: ``False``
#             Whether to allow a singular covariance matrix. This is ignored if `cov` is
#             a `Covariance` object.
#         seed : {None, int, np.random.RandomState, np.random.Generator}, optional
#             Used for drawing random variates.
#             If `seed` is `None`, the `~np.random.RandomState` singleton is used.
#             If `seed` is an int, a new ``RandomState`` instance is used, seeded
#             with seed.
#             If `seed` is already a ``RandomState`` or ``Generator`` instance,
#             then that object is used.
#             Default is `None`.
#
#         Notes
#         -----
#         Setting the parameter `mean` to `None` is equivalent to having `mean`
#         be the zero-vector. The parameter `cov` can be a scalar, in which case
#         the covariance matrix is the identity times that value, a vector of
#         diagonal entries for the covariance matrix, a two-dimensional array_like,
#         or a `Covariance` object.
#
#         The covariance matrix `cov` may be an instance of a subclass of
#         `Covariance`, e.g. `scipy.stats.CovViaPrecision`. If so, `allow_singular`
#         is ignored.
#
#         Otherwise, `cov` must be a symmetric positive semidefinite
#         matrix when `allow_singular` is True; it must be (strictly) positive
#         definite when `allow_singular` is False.
#         Symmetry is not checked; only the lower triangular portion is used.
#         The determinant and inverse of `cov` are computed
#         as the pseudo-determinant and pseudo-inverse, respectively, so
#         that `cov` does not need to have full rank.
#
#         The probability density function for `multivariate_normal` is
#
#         .. math::
#
#             f(x) = \frac{1}{\sqrt{(2 \pi)^k \det \Sigma}}
#                    \exp\left( -\frac{1}{2} (x - \mu)^T \Sigma^{-1} (x - \mu) \right),
#
#         where :math:`\mu` is the mean, :math:`\Sigma` the covariance matrix,
#         :math:`k` the rank of :math:`\Sigma`. In case of singular :math:`\Sigma`,
#         SciPy extends this definition according to [1]_.
#
#         .. versionadded:: 0.14.0
#
#         References
#         ----------
#         .. [1] Multivariate Normal Distribution - Degenerate Case, Wikipedia,
#                https://en.wikipedia.org/wiki/Multivariate_normal_distribution#Degenerate_case
#
#         Examples
#         --------
#         >>> import numpy as np
#         >>> import matplotlib.pyplot as plt
#         >>> from scipy.stats import multivariate_normal
#
#         >>> x = np.linspace(0, 5, 10, endpoint=False)
#         >>> y = multivariate_normal.pdf(x, mean=2.5, cov=0.5); y
#         array([ 0.00108914,  0.01033349,  0.05946514,  0.20755375,  0.43939129,
#                 0.56418958,  0.43939129,  0.20755375,  0.05946514,  0.01033349])
#         >>> fig1 = plt.figure()
#         >>> ax = fig1.add_subplot(111)
#         >>> ax.plot(x, y)
#         >>> plt.show()
#
#         Alternatively, the object may be called (as a function) to fix the mean
#         and covariance parameters, returning a "frozen" multivariate normal
#         random variable:
#
#         >>> rv = multivariate_normal(mean=None, cov=1, allow_singular=False)
#         >>> # Frozen object with the same methods but holding the given
#         >>> # mean and covariance fixed.
#
#         The input quantiles can be any shape of array, as long as the last
#         axis labels the components.  This allows us for instance to
#         display the frozen pdf for a non-isotropic random variable in 2D as
#         follows:
#
#         >>> x, y = np.mgrid[-1:1:.01, -1:1:.01]
#         >>> pos = np.dstack((x, y))
#         >>> rv = multivariate_normal([0.5, -0.2], [[2.0, 0.3], [0.3, 0.5]])
#         >>> fig2 = plt.figure()
#         >>> ax2 = fig2.add_subplot(111)
#         >>> ax2.contourf(x, y, rv.pdf(pos))
#
# FILE
#     /home/ephrem/miniconda3/envs/my_space/lib/python3.10/site-packages/benchmark_functions/benchmark_functions.py
